# %% [markdown]
# # Load libraries & helper functions

# %%
from helpers import *
# %matplotlib inline

# %% [markdown]
# # Declare parameters

# %%
config.DATADIR                 = '/home/duboisjx/mnt10/LabUsers/duboisjx/data/Conte/MRI'
config.pipelineName            = 'preGLM0'
fmriRuns                       = ['movie_1','movie_2','LOI1_1','LOI2_1','socnsLOI1_1','socnsLOI2_1']
# config.pipelineName            = 'Finn'
# fmriRuns                       = ['rsBOLD_1','rsBOLD_2']
# use volume or surface data
config.useNative               = False
config.fmriFileTemplate        = '#fMRIrun#.nii.gz'
config.melodicFolder           = op.join('#fMRIrun#_hp2000.ica','filtered_func_data.ica') #the code #fMRIrun# will be replaced
config.movementRelativeRMSFile = 'Movement_RelativeRMS.txt'
config.movementRegressorsFile  = 'Movement_Regressors_dt.txt'

tmp = config.fmriFileTemplate.split('.')
if tmp[1]=='nii':
    config.isCifti = False
    config.parcellationName        = 'shen2013'
    config.parcellationFile        = '/home/duboisjx/mnt10/LabUsers/duboisjx/data/parcellations/shenetal_neuroimage2013_new/shen_2.5mm_268_parcellation.nii.gz'
    config.nParcels                = 268
elif tmp[1]=='dtseries':
    config.isCifti = True
    config.parcellationName        = 'Glasser'
    config.parcellationFile        = '/home/duboisjx/mnt10/LabUsers/duboisjx/data/parcellations/Glasser2016/Parcels.dlabel.nii'
    config.nParcels                = 360
else:
    print 'unknown file extension'

config.preWhitening            = False
config.maskParcelswithAll      = True
config.maskParcelswithGM       = False
if config.maskParcelswithGM:
    config.parcellationName    = config.parcellationName + '_GM'

# submit jobs with sge
config.queue        = False
launchSubproc       = True
parallelEnvironment = 'smp' #'openmp'
    
subjects  = [s for s in sorted(os.listdir(config.DATADIR)) if len(s)==6 and s[0:2]=='CC']
print subjects
# Out:
# ['CC0003', 'CC0005', 'CC0006', 'CC0007', 'CC0008', 'CC0010', 'CC0011', 'CC0012', 'CC0014', 'CC0024', 'CC0025', 'CC0027', 'CC0029', 'CC0033', 'CC0041', 'CC0046', 'CC0049', 'CC0056', 'CC0058', 'CC0059', 'CC0060', 'CC0061', 'CC0063', 'CC0064', 'CC0065', 'CC0068', 'CC0069', 'CC0070', 'CC0071', 'CC0074', 'CC0076', 'CC0077', 'CC0078', 'CC0079', 'CC0080', 'CC0081', 'CC0082', 'CC0085', 'CC0087', 'CC0088', 'CC0089', 'CC0091', 'CC0092', 'CC0096', 'CC0100', 'CC0101', 'CC0104', 'CC0105', 'CC0106', 'CC0108', 'CC0110', 'CC0111', 'CC0112', 'CC0114', 'CC0115', 'CC0116', 'CC0117', 'CC0118', 'CC0124', 'CC0126']

# %% [markdown]
# # Do work

# %%
config.overwrite               = False
config.Operations              = config.operationDict[config.pipelineName]

if config.pipelineName in ['SiegelA','SiegelB']:
    config.useFIX              = True
else:
    config.useFIX              = False

returnhere = os.getcwd()

# do the work
config.joblist = list()
iSub    = 0
for subject in subjects:
    config.subject = str(subject)
    iRun = 0
    for config.fmriRun in fmriRuns:
        runPipelinePar(launchSubproc=launchSubproc)
        iRun=iRun+1
        if len(config.joblist)>=8:
            # wait until all tasks are done
            checkProgress(verbose=True)
            config.joblist = list()
    iSub = iSub + 1

if len(config.joblist)>0:
    checkProgress(verbose=True) 

# make symlinks
keepSub = np.zeros((len(subjects),len(fmriRuns)),dtype=np.bool_)
iSub    = 0
for subject in subjects:
    config.subject = str(subject)
    iRun = 0
    for config.fmriRun in fmriRuns:
        keepSub[iSub,iRun] = runPipelinePar(launchSubproc=False)
        if keepSub[iSub,iRun]:
            os.chdir(op.dirname(buildpath()))
            if op.exists(buildpath()+'_'+config.pipelineName):
                os.remove(buildpath()+'_'+config.pipelineName)
            os.symlink(op.basename(buildpath()),
                op.basename(buildpath())+'_'+config.pipelineName)
            if op.exists(op.join(buildpath(),config.fmriRun+'_'+config.pipelineName+config.ext)):
                os.remove(op.join(buildpath(),config.fmriRun+'_'+config.pipelineName+config.ext))
            os.chdir(buildpath())
            os.symlink(op.basename(config.fmriFile_dn),
                  config.fmriRun+'_'+config.pipelineName+config.ext)
            print '{} -- {} -- OK'.format(config.subject,config.fmriRun)
            os.chdir(returnhere)
        iRun=iRun+1
    iSub = iSub + 1
# Out:
# submitted sCC0003_movie_1_preGLM0_ciftiFalse_20180511174225912
# submitted sCC0003_movie_2_preGLM0_ciftiFalse_20180511174226570
# submitted sCC0006_movie_1_preGLM0_ciftiFalse_20180511174227800
# submitted sCC0006_movie_2_preGLM0_ciftiFalse_20180511174228466
# submitted sCC0006_LOI2_1_preGLM0_ciftiFalse_20180511174228956
# submitted sCC0006_socnsLOI1_1_preGLM0_ciftiFalse_20180511174229407
# submitted sCC0006_socnsLOI2_1_preGLM0_ciftiFalse_20180511174230314
# submitted sCC0007_movie_1_preGLM0_ciftiFalse_20180511174231099
# Waiting for 8 jobs to complete...
# Waiting for 5 jobs to complete...
# Waiting for 4 jobs to complete...
# Waiting for 4 jobs to complete...
# Waiting for 3 jobs to complete...
# Waiting for 1 jobs to complete...
# Waiting for 1 jobs to complete...
# All done!!
# submitted sCC0007_movie_2_preGLM0_ciftiFalse_20180511174932177
# submitted sCC0007_LOI1_1_preGLM0_ciftiFalse_20180511174932903
# submitted sCC0007_LOI2_1_preGLM0_ciftiFalse_20180511174933303
# submitted sCC0007_socnsLOI1_1_preGLM0_ciftiFalse_20180511174933742
# submitted sCC0007_socnsLOI2_1_preGLM0_ciftiFalse_20180511174934211
# submitted sCC0008_movie_1_preGLM0_ciftiFalse_20180511174935436
# submitted sCC0008_movie_2_preGLM0_ciftiFalse_20180511174936589
# submitted sCC0008_LOI1_1_preGLM0_ciftiFalse_20180511174937234
# Waiting for 8 jobs to complete...
# Waiting for 5 jobs to complete...
# Waiting for 3 jobs to complete...
# Waiting for 1 jobs to complete...
# Waiting for 1 jobs to complete...
# All done!!
# submitted sCC0008_LOI2_1_preGLM0_ciftiFalse_20180511175438198
# submitted sCC0008_socnsLOI1_1_preGLM0_ciftiFalse_20180511175438644
# submitted sCC0008_socnsLOI2_1_preGLM0_ciftiFalse_20180511175439089
# submitted sCC0012_movie_1_preGLM0_ciftiFalse_20180511175439982
# submitted sCC0012_movie_2_preGLM0_ciftiFalse_20180511175440698
# submitted sCC0012_LOI1_1_preGLM0_ciftiFalse_20180511175441269
# submitted sCC0012_LOI2_1_preGLM0_ciftiFalse_20180511175441794
# submitted sCC0012_socnsLOI1_1_preGLM0_ciftiFalse_20180511175442333
# Waiting for 8 jobs to complete...
# Waiting for 6 jobs to complete...
# Waiting for 5 jobs to complete...
# Waiting for 1 jobs to complete...
# Waiting for 1 jobs to complete...
# All done!!
# submitted sCC0012_socnsLOI2_1_preGLM0_ciftiFalse_20180511175944155
# submitted sCC0027_movie_1_preGLM0_ciftiFalse_20180511175945987
# submitted sCC0027_movie_2_preGLM0_ciftiFalse_20180511175946849
# submitted sCC0027_LOI1_1_preGLM0_ciftiFalse_20180511175947287
# submitted sCC0027_LOI2_1_preGLM0_ciftiFalse_20180511175948364
# submitted sCC0027_socnsLOI1_1_preGLM0_ciftiFalse_20180511175948860
# submitted sCC0027_socnsLOI2_1_preGLM0_ciftiFalse_20180511175949392
# submitted sCC0029_movie_1_preGLM0_ciftiFalse_20180511175950191
# Waiting for 8 jobs to complete...
# Waiting for 5 jobs to complete...
# Waiting for 3 jobs to complete...
# Waiting for 2 jobs to complete...
# Waiting for 1 jobs to complete...
# All done!!
# submitted sCC0029_movie_2_preGLM0_ciftiFalse_20180511180451037
# submitted sCC0029_LOI1_1_preGLM0_ciftiFalse_20180511180451499
# submitted sCC0029_LOI2_1_preGLM0_ciftiFalse_20180511180451976
# submitted sCC0029_socnsLOI1_1_preGLM0_ciftiFalse_20180511180452492
# submitted sCC0029_socnsLOI2_1_preGLM0_ciftiFalse_20180511180452901
# submitted sCC0033_movie_1_preGLM0_ciftiFalse_20180511180453879
# submitted sCC0033_movie_2_preGLM0_ciftiFalse_20180511180454490
# submitted sCC0033_LOI1_1_preGLM0_ciftiFalse_20180511180454945
# Waiting for 8 jobs to complete...
# Waiting for 5 jobs to complete...
# Waiting for 2 jobs to complete...
# Waiting for 1 jobs to complete...
# All done!!
# submitted sCC0033_LOI2_1_preGLM0_ciftiFalse_20180511180855337
# submitted sCC0033_socnsLOI1_1_preGLM0_ciftiFalse_20180511180855568
# submitted sCC0033_socnsLOI2_1_preGLM0_ciftiFalse_20180511180855676
# submitted sCC0041_movie_1_preGLM0_ciftiFalse_20180511180855845
# submitted sCC0041_LOI1_1_preGLM0_ciftiFalse_20180511180856001
# submitted sCC0041_LOI2_1_preGLM0_ciftiFalse_20180511180856214
# submitted sCC0041_socnsLOI1_1_preGLM0_ciftiFalse_20180511180856360
# submitted sCC0041_socnsLOI2_1_preGLM0_ciftiFalse_20180511180856506
# Waiting for 8 jobs to complete...
# Waiting for 8 jobs to complete...
# Waiting for 7 jobs to complete...
# Waiting for 3 jobs to complete...
# Waiting for 2 jobs to complete...
# All done!!
# submitted sCC0114_LOI1_1_preGLM0_ciftiFalse_20180511183908725
# submitted sCC0114_LOI2_1_preGLM0_ciftiFalse_20180511183908794
# submitted sCC0114_socnsLOI1_1_preGLM0_ciftiFalse_20180511183908891
# submitted sCC0114_socnsLOI2_1_preGLM0_ciftiFalse_20180511183908987
# submitted sCC0117_movie_1_preGLM0_ciftiFalse_20180511183909081
# submitted sCC0117_movie_2_preGLM0_ciftiFalse_20180511183909159
# Waiting for 8 jobs to complete...
# Waiting for 2 jobs to complete...
# Waiting for 1 jobs to complete...
# All done!!
# submitted sCC0117_LOI1_1_preGLM0_ciftiFalse_20180511184209391
# submitted sCC0117_LOI2_1_preGLM0_ciftiFalse_20180511184209453
# submitted sCC0117_socnsLOI1_1_preGLM0_ciftiFalse_20180511184209503
# submitted sCC0117_socnsLOI2_1_preGLM0_ciftiFalse_20180511184209579
# Waiting for 4 jobs to complete...
# Waiting for 2 jobs to complete...
# Waiting for 1 jobs to complete...
# All done!!
# CC0003 -- movie_1 -- OK
# CC0003 -- movie_2 -- OK
# CC0006 -- movie_1 -- OK
# CC0006 -- movie_2 -- OK
# CC0006 -- LOI2_1 -- OK
# CC0006 -- socnsLOI1_1 -- OK
# CC0006 -- socnsLOI2_1 -- OK
# CC0007 -- movie_1 -- OK
# CC0007 -- movie_2 -- OK
# CC0007 -- LOI1_1 -- OK
# CC0007 -- LOI2_1 -- OK
# CC0007 -- socnsLOI1_1 -- OK
# CC0007 -- socnsLOI2_1 -- OK
# CC0008 -- movie_1 -- OK
# CC0008 -- movie_2 -- OK
# CC0008 -- LOI1_1 -- OK
# CC0008 -- LOI2_1 -- OK
# CC0008 -- socnsLOI1_1 -- OK
# CC0008 -- socnsLOI2_1 -- OK
# CC0012 -- movie_1 -- OK
# CC0012 -- movie_2 -- OK
# CC0012 -- LOI1_1 -- OK
# CC0012 -- LOI2_1 -- OK
# CC0012 -- socnsLOI1_1 -- OK
# CC0012 -- socnsLOI2_1 -- OK
# CC0027 -- movie_1 -- OK
# CC0027 -- movie_2 -- OK
# CC0027 -- LOI1_1 -- OK
# CC0027 -- LOI2_1 -- OK
# CC0027 -- socnsLOI1_1 -- OK
# CC0027 -- socnsLOI2_1 -- OK
# CC0029 -- movie_1 -- OK
# CC0029 -- movie_2 -- OK
# CC0029 -- LOI1_1 -- OK
# CC0029 -- LOI2_1 -- OK
# CC0029 -- socnsLOI1_1 -- OK
# CC0029 -- socnsLOI2_1 -- OK
# CC0033 -- movie_1 -- OK
# CC0033 -- movie_2 -- OK
# CC0033 -- LOI1_1 -- OK
# CC0033 -- LOI2_1 -- OK
# CC0033 -- socnsLOI1_1 -- OK
# CC0033 -- socnsLOI2_1 -- OK
# CC0041 -- movie_1 -- OK
# CC0041 -- LOI1_1 -- OK
# CC0041 -- LOI2_1 -- OK
# CC0041 -- socnsLOI1_1 -- OK
# CC0041 -- socnsLOI2_1 -- OK
# CC0046 -- movie_1 -- OK
# CC0046 -- movie_2 -- OK
# CC0046 -- LOI1_1 -- OK
# CC0046 -- LOI2_1 -- OK
# CC0046 -- socnsLOI1_1 -- OK
# CC0046 -- socnsLOI2_1 -- OK
# CC0049 -- LOI1_1 -- OK
# CC0049 -- LOI2_1 -- OK
# CC0049 -- socnsLOI1_1 -- OK
# CC0049 -- socnsLOI2_1 -- OK
# CC0063 -- movie_1 -- OK
# CC0063 -- movie_2 -- OK
# CC0063 -- LOI1_1 -- OK
# CC0063 -- LOI2_1 -- OK
# CC0063 -- socnsLOI1_1 -- OK
# CC0063 -- socnsLOI2_1 -- OK
# CC0068 -- movie_1 -- OK
# CC0068 -- movie_2 -- OK
# CC0068 -- LOI1_1 -- OK
# CC0068 -- LOI2_1 -- OK
# CC0068 -- socnsLOI1_1 -- OK
# CC0068 -- socnsLOI2_1 -- OK
# CC0080 -- movie_1 -- OK
# CC0080 -- movie_2 -- OK
# CC0080 -- LOI1_1 -- OK
# CC0080 -- LOI2_1 -- OK
# CC0080 -- socnsLOI1_1 -- OK
# CC0080 -- socnsLOI2_1 -- OK
# CC0081 -- movie_1 -- OK
# CC0081 -- movie_2 -- OK
# CC0081 -- LOI1_1 -- OK
# CC0081 -- LOI2_1 -- OK
# CC0081 -- socnsLOI1_1 -- OK
# CC0081 -- socnsLOI2_1 -- OK
# CC0085 -- movie_1 -- OK
# CC0085 -- movie_2 -- OK
# CC0085 -- LOI1_1 -- OK
# CC0085 -- LOI2_1 -- OK
# CC0085 -- socnsLOI1_1 -- OK
# CC0085 -- socnsLOI2_1 -- OK
# CC0104 -- movie_1 -- OK
# CC0104 -- movie_2 -- OK
# CC0104 -- LOI1_1 -- OK
# CC0104 -- LOI2_1 -- OK
# CC0104 -- socnsLOI1_1 -- OK
# CC0104 -- socnsLOI2_1 -- OK
# CC0106 -- movie_1 -- OK
# CC0106 -- movie_2 -- OK
# CC0106 -- LOI1_1 -- OK
# CC0106 -- LOI2_1 -- OK
# CC0106 -- socnsLOI1_1 -- OK
# CC0106 -- socnsLOI2_1 -- OK
# CC0108 -- movie_1 -- OK
# CC0108 -- movie_2 -- OK
# CC0108 -- LOI1_1 -- OK
# CC0108 -- LOI2_1 -- OK
# CC0108 -- socnsLOI1_1 -- OK
# CC0108 -- socnsLOI2_1 -- OK
# CC0111 -- movie_1 -- OK
# CC0111 -- movie_2 -- OK
# CC0111 -- LOI1_1 -- OK
# CC0111 -- LOI2_1 -- OK
# CC0111 -- socnsLOI1_1 -- OK
# CC0111 -- socnsLOI2_1 -- OK
# CC0114 -- movie_1 -- OK
# CC0114 -- movie_2 -- OK
# CC0114 -- LOI1_1 -- OK
# CC0114 -- LOI2_1 -- OK
# CC0114 -- socnsLOI1_1 -- OK
# CC0114 -- socnsLOI2_1 -- OK
# CC0117 -- movie_1 -- OK
# CC0117 -- movie_2 -- OK
# CC0117 -- LOI1_1 -- OK
# CC0117 -- LOI2_1 -- OK
# CC0117 -- socnsLOI1_1 -- OK
# CC0117 -- socnsLOI2_1 -- OK
